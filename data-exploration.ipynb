# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dylanjcastillo/7k-books-with-metadata")

print("Path to dataset files :", path)

import pandas as pd

books = pd.read_csv(f"{path}/books.csv")
books.head()
# Out:
# Path to dataset files : C:\Users\Pc\.cache\kagglehub\datasets\dylanjcastillo\7k-books-with-metadata\versions\3
#           isbn13      isbn10           title subtitle  \
# 0  9780002005883  0002005883          Gilead      NaN
# 1  9780002261982  0002261987    Spider's Web  A Novel
# 2  9780006163831  0006163831    The One Tree      NaN
# 3  9780006178736  0006178731  Rage of angels      NaN
# 4  9780006280897  0006280897  The Four Loves      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2             Stephen R. Donaldson               American fiction
# 3                   Sidney Sheldon                        Fiction
# 4              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
sns.heatmap(books.isna().transpose(), cbar=False, ax=ax)
#Une heatmap (carte de chaleur) est un graphique qui utilise des couleurs pour représenter des valeurs dans un tableau ou une matrice.
plt.xlabel("columns")
plt.ylabel("rows")
plt.title("Missing values in books dataset")
plt.show()

# %%
books.isna().transpose().head()
# Out:
#            0      1      2      3      4      5      6      7      8     \
# isbn13    False  False  False  False  False  False  False  False  False
# isbn10    False  False  False  False  False  False  False  False  False
# title     False  False  False  False  False  False  False  False  False
# subtitle   True  False   True   True   True   True   True  False  False
# authors   False  False  False  False  False  False  False  False  False
#
#            9     ...   6800   6801   6802   6803   6804   6805   6806   6807  \
# isbn13    False  ...  False  False  False  False  False  False  False  False
# isbn10    False  ...  False  False  False  False  False  False  False  False
# title     False  ...  False  False  False  False  False  False  False  False
# subtitle   True  ...   True   True   True   True   True  False   True   True
# authors   False  ...  False  False  False  False  False  False  False  False
#
#            6808   6809
# isbn13    False  False
# ...

# %%
import numpy as np
books["missing_description"] = np.where(books["description"].isna(), 1, 0)
books["age_of_book"]= 2025 - books["published_year"]

# %%
columns_of_interest=["num_pages", "age_of_book","missing_description","average_rating"]
#est un tableau qui montre la force et le sens de la relation entre plusieurs variables numériques d’un dataset.
#Chaque case de la matrice indique le coefficient de corrélation entre deux variables :
correlation_matrix=books[columns_of_interest].corr(method="spearman")
#Si la valeur est proche de 1, les deux variables évoluent ensemble (corrélation positive).
#Si la valeur est proche de -1, elles évoluent en sens opposé (corrélation négative).
#Si la valeur est proche de 0, il n’y a pas de relation linéaire entre elles.
sns.set_theme(style="white")
plt.figure(figsize=(5,4))
heatmap=sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", cbar_kws={"label": "spearman correlation"})
heatmap.set_title("Correlation Matrix of Selected Features", fontdict={"fontsize":18}, pad=16)
plt.show()

# %%
book_missing= books[ ~books["description"].isna() 
      & ~ books["average_rating"].isna() 
      & ~ books["num_pages"].isna() 
      &  ~ books["published_year"].isna()]

# %%
book_missing
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006163831  0006163831
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# ...             ...         ...
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6808  9789027712059  9027712050
# 6809  9789042003408  9042003405
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                          The One Tree
# 3                                        Rage of angels
# 4                                        The Four Loves
# ...                                                 ...
# 6803                                Journey to the East
# 6804  The Monk Who Sold His Ferrari: A Fable About F...
# 6805                                          I Am that
# ...

# %%
book_missing["categories"].value_counts().reset_index().sort_values("count",ascending=False)
# Out:
#                        categories  count
# 0                         Fiction   2523
# 1                Juvenile Fiction    534
# 2       Biography & Autobiography    391
# 3                         History    258
# 4              Literary Criticism    164
# ..                            ...    ...
# 526                       Courage      1
# 527   Otherland (Imaginary place)      1
# 528                       Animals      1
# 529  Children of divorced parents      1
# 530                Catholic women      1
#
# [531 rows x 2 columns]

# %%
book_missing
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006163831  0006163831
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# ...             ...         ...
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6808  9789027712059  9027712050
# 6809  9789042003408  9042003405
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                          The One Tree
# 3                                        Rage of angels
# 4                                        The Four Loves
# ...                                                 ...
# 6803                                Journey to the East
# 6804  The Monk Who Sold His Ferrari: A Fable About F...
# 6805                                          I Am that
# ...

# %%
book_missing["words_in_description"] = book_missing["description"].str.split().str.len()
# Out:
# C:\Users\Pc\AppData\Local\Temp\ipykernel_16700\4057087481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_missing["words_in_description"] = book_missing["description"].str.split().str.len()

# %%
book_missing
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006163831  0006163831
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# ...             ...         ...
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6808  9789027712059  9027712050
# 6809  9789042003408  9042003405
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                          The One Tree
# 3                                        Rage of angels
# 4                                        The Four Loves
# ...                                                 ...
# 6803                                Journey to the East
# 6804  The Monk Who Sold His Ferrari: A Fable About F...
# 6805                                          I Am that
# ...

# %%
book_missing.loc[book_missing["words_in_description"].between(5,14),"description_length"] = "short"
#On sélectionne les lignes du DataFrame book_missing où la colonne "words_in_description" contient une valeur comprise entre 1 et 4 (inclus).
#Pour ces lignes, on attribue la valeur "short" à la colonne "description_length".
book_missing[book_missing["description_length"] == "short"]
# Out:
# C:\Users\Pc\AppData\Local\Temp\ipykernel_16700\2931581525.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   book_missing.loc[book_missing["words_in_description"].between(5,14),"description_length"] = "short"
#              isbn13      isbn10  \
# 2     9780006163831  0006163831
# 38    9780007103676  0007103670
# 70    9780007150304  000715030X
# 77    9780007158515  0007158513
# 84    9780007178636  0007178638
# ...             ...         ...
# 6715  9781929610259  1929610254
# 6726  9781931082884  193108288X
# 6757  9781932429237  1932429239
# 6776  9781933618081  1933618086
# 6795  9784770028013  4770028016
#
#                                               title  \
# 2                                      The One Tree
# ...

# %%
book_missing_25_words = book_missing[book_missing["words_in_description"] >= 25]
book_missing
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# 5     9780006280934  0006280935
# ...             ...         ...
# 6802  9788172235222  8172235224
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6808  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 3                                        Rage of angels
# 4                                        The Four Loves
# 5                                   The Problem of Pain
# ...                                                 ...
# 6802                                  Mistaken Identity
# 6803                                Journey to the East
# 6804  The Monk Who Sold His Ferrari: A Fable About F...
# ...

# %%
book_missing_25_words ["title_and_subtitle"] = (
    np.where(book_missing_25_words["subtitle"].isna(), 
             book_missing_25_words["title"],
             book_missing_25_words[["title","subtitle"]].astype(str).agg(" : ".join, axis=1))
)
#On crée une nouvelle colonne "title_and_subtitle" dans le DataFrame book_missing_25_words.
#Pour chaque ligne :
#Si la colonne "subtitle" est manquante (isna()), on met seulement le titre.
#Sinon, on combine le titre et le sous-titre en les séparant par " :
book_missing_25_words
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# 5     9780006280934  0006280935
# ...             ...         ...
# 6802  9788172235222  8172235224
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6808  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 3                                        Rage of angels
# 4                                        The Four Loves
# 5                                   The Problem of Pain
# ...                                                 ...
# 6802                                  Mistaken Identity
# 6803                                Journey to the East
# 6804  The Monk Who Sold His Ferrari: A Fable About F...
# ...

# %%
book_missing_25_words["tagged_description"]= book_missing_25_words[["isbn13","description"]].astype(str).agg(":".join, axis=1)
book_missing_25_words
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 3     9780006178736  0006178731
# 4     9780006280897  0006280897
# 5     9780006280934  0006280935
# ...             ...         ...
# 6802  9788172235222  8172235224
# 6803  9788173031014  8173031010
# 6804  9788179921623  817992162X
# 6805  9788185300535  8185300534
# 6808  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 3                                        Rage of angels
# 4                                        The Four Loves
# 5                                   The Problem of Pain
# ...                                                 ...
# 6802                                  Mistaken Identity
# 6803                                Journey to the East
# 6804  The Monk Who Sold His Ferrari: A Fable About F...
# ...

# %%
( 
    book_missing_25_words
    .drop(["subtitle","missing_description","words_in_description","age_of_book"], axis=1)
    .to_csv("cleaned_books.csv", index=False)
)
